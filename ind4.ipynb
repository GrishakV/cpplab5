# %%
from PIL import Image
import requests
from io import BytesIO
import matplotlib.pyplot as plt
# %matplotlib inline

response = requests.get('https://memepedia.ru/wp-content/uploads/2020/02/volk-s-palcem-u-viska-10.jpg')
img = Image.open(BytesIO(response.content))

plt.imshow(img)
